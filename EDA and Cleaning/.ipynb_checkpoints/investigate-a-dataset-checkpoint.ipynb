# %% [markdown]
# # Investigate a Dataset (Titanic)
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#Dataset">Dataset</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# In this Project, we try to extract any useful information about each person on the titanic and visualize our finding in a manner that is easy to follow in order to help us better understand the factors than affected people's survival rates.
#
# <font color = 'green'>Libraries used: </font>
# <font color = 'brown'> Pandas, Numpy, Matplotlib and Seaborn</font>

# %% [markdown]
# <a id='Dataset'></a>
# ## Dataset
#
# we will be investigating the 'titanic- Machine Learning from Disaster' Dataset from kaggle - <a href='https://www.kaggle.com/competitions/titanic/data'>Link</a>

# %% [markdown]
# ![Data%20Dictionary.PNG](attachment:Data%20Dictionary.PNG)

# %% [markdown]
# ![Variable%20Notes.PNG](attachment:Variable%20Notes.PNG)

# %%
#importing all the libraries used
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import matplotlib.dates as pld
from datetime import datetime
import seaborn as sns

#display plots inline (in the notebook)
# %matplotlib inline 

sns.set(rc={'figure.figsize':[9,9]},font_scale=1.2) #change default plot size and font scale for a better look

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %% [markdown]
# ### Reading the Data

# %%
df = pd.read_csv("../Datasets/train.csv",index_col='PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# <font color = 'blue'>There are some null values in the columns 'Age' and 'Cabin'

# %%
# for ele in ['Age','Fare','Cabin','Embarked']:
#     print(f' {ele} : {(df[ele]})

df[['Age','Cabin']].isnull().mean()
# Out:
# Age      0.198653
# Cabin    0.771044
# dtype: float64

# %% [markdown]
# <font color = 'blue'> over 70% of 'Cabin' is null.. </font>

# %%
#drop 'Cabin' column
df.drop('Cabin',axis = 1, inplace = True)

# %%
#drop rows with null values
df.dropna(inplace = True)

# %%
df.isnull().mean()
# Out:
# Survived    0.0
# Pclass      0.0
# Name        0.0
# Sex         0.0
# Age         0.0
# SibSp       0.0
# Parch       0.0
# Ticket      0.0
# Fare        0.0
# Embarked    0.0
# dtype: float64

# %%
df.shape[0]
# Out:
# 712

# %% [markdown]
# ## Inspecting the keys

# %%
df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Pclass':'Ticket_class',
    'SibSp' :'Siblings_Spouses',
    'Parch' :'Parents_Children',
})

# %%
df.keys()
# Out:
# Index(['Survived', 'Ticket_class', 'Name', 'Sex', 'Age', 'Siblings_Spouses',
#        'Parents_Children', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Inspecting the Values

# %%
df['Survived'] = df['Survived'].map({0:'No',1:'Yes'})
df['Ticket_class'] = df['Ticket_class'].map({1:'1st',2:'2nd',3:'3rd'})
df['Embarked'] = df['Embarked'].map({
    'C':'Cherbourg',
    'Q':'Queenstown',
    'S': 'Southampton'
})


df['Sex'] = df.Sex.apply(lambda x: x.capitalize())

# %%
df.head()
# Out:
#             Survived Ticket_class  \
# PassengerId
# 1                 No          3rd
# 2                Yes          1st
# 3                Yes          3rd
# 4                Yes          1st
# 5                 No          3rd
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    Male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  38.0
# 3                                       Heikkinen, Miss. Laina  Female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  35.0
# 5                                     Allen, Mr. William Henry    Male  35.0
#
#              Siblings_Spouses  Parents_Children            Ticket     Fare  \
# PassengerId
# 1                           1                 0         A/5 21171   7.2500
# 2                           1                 0          PC 17599  71.2833
# ...

# %% [markdown]
# <font color = 'blue'> counting the Ticket Codes in the 'Ticket' Column (Next to number)</font>

# %%
df.Ticket.map(lambda x: x.split()[0] if not(x.strip().isnumeric()) else np.nan).count()
# Out:
# 193

# %% [markdown]
# <font color = 'blue'> Only 10% of the tickets have codes, they will be removed</font>

# %%
df['Ticket'] = df.Ticket.map(lambda x: ''.join(i for i in x if i.isdigit()))

# %%
df.drop(df[df['Ticket'] == ''].index,inplace = True)

# %%
df['Ticket'] = df['Ticket'].astype('int64')

# %% [markdown]
# <font color = 'blue'>'Name' column is useless</font>

# %%
df.drop('Name',axis = 1, inplace =True)

# %%
df.head()
# Out:
#             Survived Ticket_class     Sex   Age  Siblings_Spouses  \
# PassengerId
# 1                 No          3rd    Male  22.0                 1
# 2                Yes          1st  Female  38.0                 1
# 3                Yes          3rd  Female  26.0                 0
# 4                Yes          1st  Female  35.0                 1
# 5                 No          3rd    Male  35.0                 0
#
#              Parents_Children    Ticket     Fare     Embarked
# PassengerId
# 1                           0    521171   7.2500  Southampton
# 2                           0     17599  71.2833    Cherbourg
# 3                           0  23101282   7.9250  Southampton
# 4                           0    113803  53.1000  Southampton
# 5                           0    373450   8.0500  Southampton

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 708 entries, 1 to 891
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Survived          708 non-null    object
#  1   Ticket_class      708 non-null    object
#  2   Sex               708 non-null    object
#  3   Age               708 non-null    float64
#  4   Siblings_Spouses  708 non-null    int64
#  5   Parents_Children  708 non-null    int64
#  6   Ticket            708 non-null    int64
#  7   Fare              708 non-null    float64
#  8   Embarked          708 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 55.3+ KB

# %% [markdown]
# ## Writing file

# %%
df.to_csv("../Datasets/EDA.csv")

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %%
cats = ['Survived','Ticket_class','Sex','Siblings_Spouses','Parents_Children','Embarked']
nums = ['Age','Ticket','Fare']

# %%
for cat in cats:
    plt.pie(df[cat].value_counts(),labels=df[cat].unique(),autopct='%.1f%%')
    plt.title(f'Percentage of {cat}',fontsize=20)
    plt.show();

# %% [markdown]
# ### Observations:
#
# survived: imbalanced classes, will be addresssed when training the model
#
# Ticket_class: the distribution of classes in the data might point to that some
# people are missing/ un-accounted for. as 1st class has more people than 2nd.
# which should have almost double 1st class.
#
# Sex: ~15% increase in males. which might indicate that some women are unaccounted for. however,
# the difference is small enough that we can assume it's in the margin of error (acceptable)
#
# Siblings_Spouses:more than half of the people onboard are with one Sibling_Spouse, probably Spouses.
#
# Parents_Children: 72% of people are without parents or children. further supporting the idea that most
# of people onboard are couples.
#
# Embarked: 77% Southampton... nothing to conclude

# %%
df[(df['Parents_Children'] == 0) & (df['Siblings_Spouses'] == 0)].groupby('Sex').describe()['Age']
# Out:
#         count       mean        std   min    25%   50%    75%   max
# Sex
# Female   98.0  29.744898  11.440623   5.0  22.00  28.0  35.75  63.0
# Male    300.0  32.910000  13.210360  11.0  22.75  30.0  40.00  80.0

# %%
for num in nums:
    sns.kdeplot(x=num,hue='Survived',data =df,common_norm=False,bw_adjust=0.3)
    plt.xlim(df[num].min(),df[num].max())
    plt.title(f' Distribution of {num}')
    plt.show()

# %% [markdown]
# ## Observations:

# %%
df['Age'] = df.Age.astype('int')

# %%
df['Age'].describe()
# Out:
# count    708.000000
# mean      29.607345
# std       14.517065
# min        0.000000
# 25%       20.000000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df[df['Age'] < 18].groupby('Survived').describe()['Age']
# Out:
#           count       mean       std  min  25%   50%   75%   max
# Survived
# No         52.0  10.384615  5.667776  1.0  5.5  10.5  16.0  17.0
# Yes        61.0   7.803279  6.233832  0.0  3.0   5.0  15.0  17.0

# %%
df[(df['Age'] >= 18) & (df['Age'] < 50)].groupby('Survived').describe()['Age']
# Out:
#           count       mean       std   min   25%   50%   75%   max
# Survived
# No        322.0  29.782609  8.446051  18.0  23.0  28.0  36.0  49.0
# Yes       200.0  30.805000  8.281903  18.0  24.0  30.0  36.0  49.0

# %%
df[df['Age'] >= 50].groupby('Survived').describe()['Age']
# Out:
#           count       mean       std   min    25%   50%   75%   max
# Survived
# No         47.0  58.361702  6.841134  50.0  52.00  57.0  63.0  74.0
# Yes        26.0  55.846154  6.491177  50.0  51.25  54.0  58.0  80.0

# %% [markdown]
# Age:
# if a passenger is under 18. the younger he is, the more likely they survive (children).
# if a passenger is over 50, the younger he is, the more likely they survive.
# However, between 18 and 50, age is not a factor.

# %%
sns.displot(x='Ticket',data =df)

# %% [markdown]
# Ticket: Regardless of Survival Status, Tickets are clustered into 3 gropus. which might represent
# the different Embarking station's naming schemes... needs further analysis

# %%
#first Group
sns.displot(x='Ticket',hue='Embarked',data =df,multiple='dodge')
plt.xlim([df['Ticket'].min(),0.6e6])
# Out:
# (3.0, 600000.0)

# %% [markdown]
# Ticket: Upon closer inspection, there seems to be no connection between the ticket number and Embarked. There seems to be nothing to conclude from this Column and it should be dropped. all the info that this column might contain that is relevant to our target is already prevelent in other columns (Ex: Embarked and Ticket_Class)

# %%
df.drop('Ticket',axis = 1,inplace = True)

# %%
df.keys()
# Out:
# Index(['Survived', 'Ticket_class', 'Sex', 'Age', 'Siblings_Spouses',
#        'Parents_Children', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df[df['Fare'] <= 0].shape[0]
# Out:
# 3

# %% [markdown]
# only 3 people have fare less than or equal 0

# %%
df[df['Fare'] <= 0]
# Out:
#             Survived Ticket_class   Sex  Age  Siblings_Spouses  \
# PassengerId
# 264               No          1st  Male   40                 0
# 807               No          1st  Male   39                 0
# 823               No          1st  Male   38                 0
#
#              Parents_Children  Fare     Embarked
# PassengerId
# 264                         0   0.0  Southampton
# 807                         0   0.0  Southampton
# 823                         0   0.0  Southampton

# %% [markdown]
# These 3 passengers with 0 Fare are likely to be crew members, owners of the ship or VIP guests as they are all in their late 30s, came without any companions, and all Embarked from Southampton.

# %%
sns.kdeplot(data = df[df['Fare'] > 0],x='Fare',hue='Ticket_class',bw_adjust=0.2)
plt.xlim([0,80])
# Out:
# (0.0, 80.0)

# %%
sns.kdeplot(data = df[df['Fare'] > 0],x='Fare',hue='Ticket_class',bw_adjust=0.2)
sns.distplot(df[df['Fare'] > 80]['Fare'],kde = False)
plt.xlim(80)
plt.show();
# Out:
# G:\Apps\Anaconda\install\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.describe()[['Fare']]
# Out:
#              Fare
# count  708.000000
# mean    34.762547
# std     53.024123
# min      0.000000
# 25%      8.050000
# 50%     15.745850
# 75%     33.125000
# max    512.329200

# %%
df.groupby('Ticket_class').describe()['Fare']
# Out:
#               count       mean        std      min      25%      50%  \
# Ticket_class
# 1st           184.0  88.048121  81.293524   0.0000  33.8906  67.9500
# 2nd           173.0  21.471556  13.187429  10.5000  13.0000  15.0458
# 3rd           351.0  13.380198   9.999739   4.0125   7.7750   8.0500
#
#                     75%       max
# Ticket_class
# 1st           107.04375  512.3292
# 2nd            26.00000   73.5000
# 3rd            15.79585   56.4958

# %%
df[df['Fare'].between(0,80)].groupby('Ticket_class').describe()['Fare']
# Out:
#               count       mean        std      min     25%      50%       75%  \
# Ticket_class
# 1st           117.0  46.754312  20.717080   0.0000  28.500  49.5042  61.37920
# 2nd           173.0  21.471556  13.187429  10.5000  13.000  15.0458  26.00000
# 3rd           351.0  13.380198   9.999739   4.0125   7.775   8.0500  15.79585
#
#                   max
# Ticket_class
# 1st           79.6500
# 2nd           73.5000
# 3rd           56.4958

# %%
df[df['Fare'] > 80].groupby('Ticket_class').describe()['Fare']
# Out:
#               count        mean       std      min      25%     50%       75%  \
# Ticket_class
# 1st            67.0  160.158206  96.27115  81.8583  92.2896  133.65  211.3375
#
#                    max
# Ticket_class
# 1st           512.3292

# %% [markdown]
# Fare: most are between 5 and 30, and only 1st class goes beyond 80, and up to 512.

# %%
sns.kdeplot(x='Fare',y='Age',data= df,hue='Ticket_class',bw_adjust=0.2)
plt.xlim()
# Out:
# (-20.452083823662168, 532.7812838236622)

# %% [markdown]
# outliers are represented above 200 and at zero Fare

# %%
df[(df['Fare'] > 200) | (df['Fare'] <= 0)].shape[0]
# Out:
# 21

# %% [markdown]
# People with Fare at 0 survived, and people over 300 either survived. which signals special treatment and should not be taken into consideration while building a predictive model (outliters)

# %%
df[(df['Fare'] > 300) | (df['Fare'] <= 0)]
# Out:
#             Survived Ticket_class     Sex  Age  Siblings_Spouses  \
# PassengerId
# 259              Yes          1st  Female   35                 0
# 264               No          1st    Male   40                 0
# 680              Yes          1st    Male   36                 0
# 738              Yes          1st    Male   35                 0
# 807               No          1st    Male   39                 0
# 823               No          1st    Male   38                 0
#
#              Parents_Children      Fare     Embarked
# PassengerId
# 259                         0  512.3292    Cherbourg
# 264                         0    0.0000  Southampton
# 680                         1  512.3292    Cherbourg
# 738                         0  512.3292    Cherbourg
# 807                         0    0.0000  Southampton
# 823                         0    0.0000  Southampton

# %%
df.drop(df[(df['Fare'] > 300) | (df['Fare'] <= 0)].index,inplace = True)

# %%
df.shape[0]
# Out:
# 702

# %%
df.keys()
# Out:
# Index(['Survived', 'Ticket_class', 'Sex', 'Age', 'Siblings_Spouses',
#        'Parents_Children', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# <a id='conclusions'></a>
# # Conclusions
#
# ### Dropped Columns:
# Name, Ticket.
#
# ### survived:
# imbalanced classes, will be addresssed when training the model
#
# ### Ticket_class:
# the distribution of classes in the data might point to that some
# people are missing/ un-accounted for. as 1st class has more people than 2nd.
# which should have almost double 1st class.
#
# ### Sex:
# ~15% increase in males. which might indicate that some women are unaccounted for. however,
# the difference is small enough that we can assume it's in the margin of error (acceptable)
#
# ### Siblings_Spouses:
# more than half of the people onboard are with one Sibling_Spouse, probably Spouses.
#
# ### Parents_Children:
# 72% of people are without parents or children. further supporting the idea that most
# of people onboard are couples.
#
# ### Age:
# if a passenger is under 18. the younger he is, the more likely they survive (children). <br>
# if a passenger is over 50, the younger he is, the more likely they survive. <br>
# However, between 18 and 50, age is not a factor.
#
# ### Fare:
# People with Fare at 0 survived, and people over 300 either survived. which signals special treatment and should not be taken into consideration while building a predictive model (outliters)

# %%
def Cleaning(df,y=True):
    """ Cleans raw dataset for Preprocessing
    
    input: A Dataframe that has the keys:
        ['Survived', 'Pclass', 'Name',
        'Sex', 'Age', 'SibSp', 'Parch', 
        'Ticket','Fare', 'Cabin', 'Embarked']
        
    returns Cleaned Dataset with no Business outliers or np.nan if no entries remained."""

    df = df.rename(columns={
        'Pclass':'Ticket_class',
        'SibSp' :'Siblings_Spouses',
        'Parch' :'Parents_Children',
    })

    if y:
        df['Survived'] = df['Survived'].map({0:'No',1:'Yes'})
    # df['Ticket_class'] = df['Ticket_class'].map({1:'1st',2:'2nd',3:'3rd'})
    df['Embarked'] = df['Embarked'].map({
        'C':'Cherbourg',
        'Q':'Queenstown',
        'S': 'Southampton'
    })

    df['Sex'] = df.Sex.apply(lambda x: x.capitalize())
    
    df.drop('Cabin',axis = 1, inplace = True)
    df.drop('Ticket',axis = 1,inplace = True)
    df.drop('Name',axis = 1, inplace = True)
    df.dropna(inplace = True)
    df['Age'] = df.Age.astype('int')
    df.drop(df[(df['Fare'] > 350) | (df['Fare'] <= 0)].index,inplace = True)
    
    if df.shape[0] == 0:
        return np.nan
    else:
        return df

# %%
# df2 = df.copy()

# %%
df = pd.read_csv("../Datasets/train.csv",index_col='PassengerId')

# %%
df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = Cleaning(df)

# %%
# df2.shape, df.shape #script test

# %%
df.to_csv("../Datasets/train_clean.csv")

# %%
df = pd.read_csv("../Datasets/test.csv",index_col='PassengerId')

# %%
df = Cleaning(df,y=False)

# %%
df.to_csv("../Datasets/test_clean.csv")
